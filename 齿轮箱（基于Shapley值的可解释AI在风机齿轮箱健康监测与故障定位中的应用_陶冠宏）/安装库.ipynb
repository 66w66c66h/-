# %%
# %pip install numpy pandas scikit-learn xgboost shap catboost lightgbm matplotlib seaborn
# Out:
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.4 MB 9.3 MB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.4 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 29.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    --------------------- ------------------ 6.0/11.2 MB 52.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 33.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    -- ------------------------------------- 8.7/124.9 MB 59.5 MB/s eta 0:00:02
#    ------ --------------------------------- 21.8/124.9 MB 52.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 34.3/124.9 MB 55.9 MB/s eta 0:00:02
# ...

# %%
# %pip install pandas numpy matplotlib natsort
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyqt5
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
